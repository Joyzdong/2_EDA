# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터 로딩, 변수 초기화

# %%
import sys
sys.stdin.encoding
# Out:
# 'cp949'

# %%
youtube = pd.read_csv('Global YouTube Statistics.csv', encoding='latin-1')

mon = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6,
       'Jul':7, 'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12}
youtube['created_month'] = youtube['created_month'].map(mon) # 두 번 실행하면 nan생김

columns = ['Country', 'Abbreviation', 'country_rank', 'Gross tertiary education enrollment (%)',
           'Population', 'Unemployment rate', 'Urban_population',
           'Latitude', 'Longitude']
country = youtube[columns].drop_duplicates().dropna().reset_index(drop=True)

# %%
youtube['Country'].unique()
# Out:
# array(['India', 'United States', nan, 'Japan', 'Russia', 'South Korea',
#        'United Kingdom', 'Canada', 'Brazil', 'Argentina', 'Chile', 'Cuba',
#        'El Salvador', 'Pakistan', 'Philippines', 'Thailand', 'Colombia',
#        'Barbados', 'Mexico', 'United Arab Emirates', 'Spain',
#        'Saudi Arabia', 'Indonesia', 'Turkey', 'Venezuela', 'Kuwait',
#        'Jordan', 'Netherlands', 'Singapore', 'Australia', 'Italy',
#        'Germany', 'France', 'Sweden', 'Afghanistan', 'Ukraine', 'Latvia',
#        'Switzerland', 'Vietnam', 'Malaysia', 'China', 'Iraq', 'Egypt',
#        'Andorra', 'Ecuador', 'Morocco', 'Peru', 'Bangladesh', 'Finland',
#        'Samoa'], dtype=object)

# %%
list(country.iterrows())
# Out:
# [(0,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        1.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 0, dtype: object),
#  (1,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                      7670.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 1, dtype: object),
#  (2,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         1.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 2, dtype: object),
#  (3,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         2.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 3, dtype: object),
#  (4,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        2.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 4, dtype: object),
#  (5,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         3.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 5, dtype: object),
#  (6,
#   Country                                          Japan
#   Abbreviation                                        JP
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)           63.2
#   Population                                 126226568.0
#   Unemployment rate                                 2.29
#   Urban_population                           115782416.0
#   Latitude                                     36.204824
#   Longitude                                   138.252924
#   Name: 6, dtype: object),
#  (7,
#   Country                                         Russia
#   Abbreviation                                        RU
#   country_rank                                       5.0
#   Gross tertiary education enrollment (%)           81.9
#   Population                                 144373535.0
#   Unemployment rate                                 4.59
#   Urban_population                           107683889.0
#   Latitude                                      61.52401
#   Longitude                                   105.318756
#   Name: 7, dtype: object),
#  (8,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         5.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 8, dtype: object),
#  (9,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        3.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 9, dtype: object),
#  (10,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         6.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 10, dtype: object),
#  (11,
#   Country                                    South Korea
#   Abbreviation                                        KR
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)           94.3
#   Population                                  51709098.0
#   Unemployment rate                                 4.15
#   Urban_population                            42106719.0
#   Latitude                                     35.907757
#   Longitude                                   127.766922
#   Name: 11, dtype: object),
#  (12,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        5.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 12, dtype: object),
#  (13,
#   Country                                    United Kingdom
#   Abbreviation                                           GB
#   country_rank                                       4797.0
#   Gross tertiary education enrollment (%)              60.0
#   Population                                     66834405.0
#   Unemployment rate                                    3.85
#   Urban_population                               55908316.0
#   Latitude                                        55.378051
#   Longitude                                       -3.435973
#   Name: 13, dtype: object),
#  (14,
#   Country                                    South Korea
#   Abbreviation                                        KR
#   country_rank                                       2.0
#   Gross tertiary education enrollment (%)           94.3
#   Population                                  51709098.0
#   Unemployment rate                                 4.15
#   Urban_population                            42106719.0
#   Latitude                                     35.907757
#   Longitude                                   127.766922
#   Name: 14, dtype: object),
#  (15,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                      6266.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 15, dtype: object),
#  (16,
#   Country                                        Canada
#   Abbreviation                                       CA
#   country_rank                                      1.0
#   Gross tertiary education enrollment (%)          68.9
#   Population                                 36991981.0
#   Unemployment rate                                5.56
#   Urban_population                           30628482.0
#   Latitude                                    56.130366
#   Longitude                                 -106.346771
#   Name: 16, dtype: object),
#  (17,
#   Country                                    South Korea
#   Abbreviation                                        KR
#   country_rank                                       3.0
#   Gross tertiary education enrollment (%)           94.3
#   Population                                  51709098.0
#   Unemployment rate                                 4.15
#   Urban_population                            42106719.0
#   Latitude                                     35.907757
#   Longitude                                   127.766922
#   Name: 17, dtype: object),
#  (18,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        6.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 18, dtype: object),
#  (19,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         8.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 19, dtype: object),
#  (20,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 20, dtype: object),
#  (21,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        7.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 21, dtype: object),
#  (22,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        8.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 22, dtype: object),
#  (23,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                        9.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 23, dtype: object),
#  (24,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                     5803.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 24, dtype: object),
#  (25,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                         9.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 25, dtype: object),
#  (26,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       11.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 26, dtype: object),
#  (27,
#   Country                                     Argentina
#   Abbreviation                                       AR
#   country_rank                                      1.0
#   Gross tertiary education enrollment (%)          90.0
#   Population                                 44938712.0
#   Unemployment rate                                9.79
#   Urban_population                           41339571.0
#   Latitude                                   -38.416097
#   Longitude                                  -63.616672
#   Name: 27, dtype: object),
#  (28,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       12.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 28, dtype: object),
#  (29,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       13.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 29, dtype: object),
#  (30,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       14.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 30, dtype: object),
#  (31,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        10.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 31, dtype: object),
#  (32,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        11.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 32, dtype: object),
#  (33,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       15.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 33, dtype: object),
#  (34,
#   Country                                    United Kingdom
#   Abbreviation                                           GB
#   country_rank                                          1.0
#   Gross tertiary education enrollment (%)              60.0
#   Population                                     66834405.0
#   Unemployment rate                                    3.85
#   Urban_population                               55908316.0
#   Latitude                                        55.378051
#   Longitude                                       -3.435973
#   Name: 34, dtype: object),
#  (35,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       16.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 35, dtype: object),
#  (36,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        13.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 36, dtype: object),
#  (37,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        14.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 37, dtype: object),
#  (38,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        15.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 38, dtype: object),
#  (39,
#   Country                                         Chile
#   Abbreviation                                       CL
#   country_rank                                      1.0
#   Gross tertiary education enrollment (%)          88.5
#   Population                                 18952038.0
#   Unemployment rate                                7.09
#   Urban_population                           16610135.0
#   Latitude                                   -35.675147
#   Longitude                                  -71.542969
#   Name: 39, dtype: object),
#  (40,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        16.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 40, dtype: object),
#  (41,
#   Country                                         Russia
#   Abbreviation                                        RU
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)           81.9
#   Population                                 144373535.0
#   Unemployment rate                                 4.59
#   Urban_population                           107683889.0
#   Latitude                                      61.52401
#   Longitude                                   105.318756
#   Name: 41, dtype: object),
#  (42,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       17.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 42, dtype: object),
#  (43,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        17.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 43, dtype: object),
#  (44,
#   Country                                          Cuba
#   Abbreviation                                       CU
#   country_rank                                     99.0
#   Gross tertiary education enrollment (%)          41.4
#   Population                                 11333483.0
#   Unemployment rate                                1.64
#   Urban_population                            8739135.0
#   Latitude                                    21.521757
#   Longitude                                  -77.781167
#   Name: 44, dtype: object),
#  (45,
#   Country                                    El Salvador
#   Abbreviation                                        SV
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)           29.4
#   Population                                   6453553.0
#   Unemployment rate                                 4.11
#   Urban_population                             4694702.0
#   Latitude                                     13.794185
#   Longitude                                    -88.89653
#   Name: 45, dtype: object),
#  (46,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       18.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 46, dtype: object),
#  (47,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                       2.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 47, dtype: object),
#  (48,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                       3.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 48, dtype: object),
#  (49,
#   Country                                       Pakistan
#   Abbreviation                                        PK
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)            9.0
#   Population                                 216565318.0
#   Unemployment rate                                 4.45
#   Urban_population                            79927762.0
#   Latitude                                     30.375321
#   Longitude                                    69.345116
#   Name: 49, dtype: object),
#  (50,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        19.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 50, dtype: object),
#  (51,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                       4.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 51, dtype: object),
#  (52,
#   Country                                    Philippines
#   Abbreviation                                        PH
#   country_rank                                       1.0
#   Gross tertiary education enrollment (%)           35.5
#   Population                                 108116615.0
#   Unemployment rate                                 2.15
#   Urban_population                            50975903.0
#   Latitude                                     12.879721
#   Longitude                                   121.774017
#   Name: 52, dtype: object),
#  (53,
#   Country                                      Thailand
#   Abbreviation                                       TH
#   country_rank                                   4026.0
#   Gross tertiary education enrollment (%)          49.3
#   Population                                 69625582.0
#   Unemployment rate                                0.75
#   Urban_population                           35294600.0
#   Latitude                                    15.870032
#   Longitude                                  100.992541
#   Name: 53, dtype: object),
#  (54,
#   Country                                      Colombia
#   Abbreviation                                       CO
#   country_rank                                      1.0
#   Gross tertiary education enrollment (%)          55.3
#   Population                                 50339443.0
#   Unemployment rate                                9.71
#   Urban_population                           40827302.0
#   Latitude                                     4.570868
#   Longitude                                  -74.297333
#   Name: 54, dtype: object),
#  (55,
#   Country                                         Russia
#   Abbreviation                                        RU
#   country_rank                                       2.0
#   Gross tertiary education enrollment (%)           81.9
#   Population                                 144373535.0
#   Unemployment rate                                 4.59
#   Urban_population                           107683889.0
#   Latitude                                      61.52401
#   Longitude                                   105.318756
#   Name: 55, dtype: object),
#  (56,
#   Country                                       Pakistan
#   Abbreviation                                        PK
#   country_rank                                       2.0
#   Gross tertiary education enrollment (%)            9.0
#   Population                                 216565318.0
#   Unemployment rate                                 4.45
#   Urban_population                            79927762.0
#   Latitude                                     30.375321
#   Longitude                                    69.345116
#   Name: 56, dtype: object),
#  (57,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       19.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 57, dtype: object),
#  (58,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        20.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 58, dtype: object),
#  (59,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        21.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 59, dtype: object),
#  (60,
#   Country                                     Barbados
#   Abbreviation                                      BB
#   country_rank                                     1.0
#   Gross tertiary education enrollment (%)         65.4
#   Population                                  287025.0
#   Unemployment rate                              10.33
#   Urban_population                             89431.0
#   Latitude                                   13.193887
#   Longitude                                 -59.543198
#   Name: 60, dtype: object),
#  (61,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       20.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 61, dtype: object),
#  (62,
#   Country                                         Mexico
#   Abbreviation                                        MX
#   country_rank                                       2.0
#   Gross tertiary education enrollment (%)           40.2
#   Population                                 126014024.0
#   Unemployment rate                                 3.42
#   Urban_population                           102626859.0
#   Latitude                                     23.634501
#   Longitude                                  -102.552784
#   Name: 62, dtype: object),
#  (63,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        22.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 63, dtype: object),
#  (64,
#   Country                                         Mexico
#   Abbreviation                                        MX
#   country_rank                                    3021.0
#   Gross tertiary education enrollment (%)           40.2
#   Population                                 126014024.0
#   Unemployment rate                                 3.42
#   Urban_population                           102626859.0
#   Latitude                                     23.634501
#   Longitude                                  -102.552784
#   Name: 64, dtype: object),
#  (65,
#   Country                                    United Arab Emirates
#   Abbreviation                                                 AE
#   country_rank                                                1.0
#   Gross tertiary education enrollment (%)                    36.8
#   Population                                            9770529.0
#   Unemployment rate                                          2.35
#   Urban_population                                      8479744.0
#   Latitude                                              23.424076
#   Longitude                                             53.847818
#   Name: 65, dtype: object),
#  (66,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       21.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 66, dtype: object),
#  (67,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        24.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 67, dtype: object),
#  (68,
#   Country                                        Canada
#   Abbreviation                                       CA
#   country_rank                                      2.0
#   Gross tertiary education enrollment (%)          68.9
#   Population                                 36991981.0
#   Unemployment rate                                5.56
#   Urban_population                           30628482.0
#   Latitude                                    56.130366
#   Longitude                                 -106.346771
#   Name: 68, dtype: object),
#  (69,
#   Country                                         Spain
#   Abbreviation                                       ES
#   country_rank                                      1.0
#   Gross tertiary education enrollment (%)          88.9
#   Population                                 47076781.0
#   Unemployment rate                               13.96
#   Urban_population                           37927409.0
#   Latitude                                    40.463667
#   Longitude                                    -3.74922
#   Name: 69, dtype: object),
#  (70,
#   Country                                      Thailand
#   Abbreviation                                       TH
#   country_rank                                      1.0
#   Gross tertiary education enrollment (%)          49.3
#   Population                                 69625582.0
#   Unemployment rate                                0.75
#   Urban_population                           35294600.0
#   Latitude                                    15.870032
#   Longitude                                  100.992541
#   Name: 70, dtype: object),
#  (71,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                       6.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 71, dtype: object),
#  (72,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        25.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 72, dtype: object),
#  (73,
#   Country                                    Saudi Arabia
#   Abbreviation                                         SA
#   country_rank                                      774.0
#   Gross tertiary education enrollment (%)            68.0
#   Population                                   34268528.0
#   Unemployment rate                                  5.93
#   Urban_population                             28807838.0
#   Latitude                                      23.885942
#   Longitude                                     45.079162
#   Name: 73, dtype: object),
#  (74,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       22.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 74, dtype: object),
#  (75,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                      2904.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 75, dtype: object),
#  (76,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        26.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 76, dtype: object),
#  (77,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       23.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 77, dtype: object),
#  (78,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        27.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 78, dtype: object),
#  (79,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        28.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 79, dtype: object),
#  (80,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        29.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 80, dtype: object),
#  (81,
#   Country                                      Thailand
#   Abbreviation                                       TH
#   country_rank                                      2.0
#   Gross tertiary education enrollment (%)          49.3
#   Population                                 69625582.0
#   Unemployment rate                                0.75
#   Urban_population                           35294600.0
#   Latitude                                    15.870032
#   Longitude                                  100.992541
#   Name: 81, dtype: object),
#  (82,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       24.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 82, dtype: object),
#  (83,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                       25.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 83, dtype: object),
#  (84,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                       7.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 84, dtype: object),
#  (85,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        30.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 85, dtype: object),
#  (86,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                        31.0
# ...
#   Gross tertiary education enrollment (%)          88.9
#   Population                                 47076781.0
#   Unemployment rate                               13.96
#   Urban_population                           37927409.0
#   Latitude                                    40.463667
#   Longitude                                    -3.74922
#   Name: 622, dtype: object),
#  (623,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                       173.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 623, dtype: object),
#  (624,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                      1944.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 624, dtype: object),
#  (625,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                      53.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 625, dtype: object),
#  (626,
#   Country                                      Colombia
#   Abbreviation                                       CO
#   country_rank                                     11.0
#   Gross tertiary education enrollment (%)          55.3
#   Population                                 50339443.0
#   Unemployment rate                                9.71
#   Urban_population                           40827302.0
#   Latitude                                     4.570868
#   Longitude                                  -74.297333
#   Name: 626, dtype: object),
#  (627,
#   Country                                    United Kingdom
#   Abbreviation                                           GB
#   country_rank                                         32.0
#   Gross tertiary education enrollment (%)              60.0
#   Population                                     66834405.0
#   Unemployment rate                                    3.85
#   Urban_population                               55908316.0
#   Latitude                                        55.378051
#   Longitude                                       -3.435973
#   Name: 627, dtype: object),
#  (628,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                       174.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 628, dtype: object),
#  (629,
#   Country                                    South Korea
#   Abbreviation                                        KR
#   country_rank                                      17.0
#   Gross tertiary education enrollment (%)           94.3
#   Population                                  51709098.0
#   Unemployment rate                                 4.15
#   Urban_population                            42106719.0
#   Latitude                                     35.907757
#   Longitude                                   127.766922
#   Name: 629, dtype: object),
#  (630,
#   Country                                    United Kingdom
#   Abbreviation                                           GB
#   country_rank                                         33.0
#   Gross tertiary education enrollment (%)              60.0
#   Population                                     66834405.0
#   Unemployment rate                                    3.85
#   Urban_population                               55908316.0
#   Latitude                                        55.378051
#   Longitude                                       -3.435973
#   Name: 630, dtype: object),
#  (631,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                       175.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 631, dtype: object),
#  (632,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                      123.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 632, dtype: object),
#  (633,
#   Country                                         Mexico
#   Abbreviation                                        MX
#   country_rank                                      33.0
#   Gross tertiary education enrollment (%)           40.2
#   Population                                 126014024.0
#   Unemployment rate                                 3.42
#   Urban_population                           102626859.0
#   Latitude                                     23.634501
#   Longitude                                  -102.552784
#   Name: 633, dtype: object),
#  (634,
#   Country                                         Spain
#   Abbreviation                                       ES
#   country_rank                                     19.0
#   Gross tertiary education enrollment (%)          88.9
#   Population                                 47076781.0
#   Unemployment rate                               13.96
#   Urban_population                           37927409.0
#   Latitude                                    40.463667
#   Longitude                                    -3.74922
#   Name: 634, dtype: object),
#  (635,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                      54.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 635, dtype: object),
#  (636,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                      122.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 636, dtype: object),
#  (637,
#   Country                                       Pakistan
#   Abbreviation                                        PK
#   country_rank                                    3554.0
#   Gross tertiary education enrollment (%)            9.0
#   Population                                 216565318.0
#   Unemployment rate                                 4.45
#   Urban_population                            79927762.0
#   Latitude                                     30.375321
#   Longitude                                    69.345116
#   Name: 637, dtype: object),
#  (638,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                       176.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 638, dtype: object),
#  (639,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                      124.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 639, dtype: object),
#  (640,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                      1795.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 640, dtype: object),
#  (641,
#   Country                                         Mexico
#   Abbreviation                                        MX
#   country_rank                                      34.0
#   Gross tertiary education enrollment (%)           40.2
#   Population                                 126014024.0
#   Unemployment rate                                 3.42
#   Urban_population                           102626859.0
#   Latitude                                     23.634501
#   Longitude                                  -102.552784
#   Name: 641, dtype: object),
#  (642,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                    5075.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 642, dtype: object),
#  (643,
#   Country                                      Indonesia
#   Abbreviation                                        ID
#   country_rank                                      34.0
#   Gross tertiary education enrollment (%)           36.3
#   Population                                 270203917.0
#   Unemployment rate                                 4.69
#   Urban_population                           151509724.0
#   Latitude                                     -0.789275
#   Longitude                                   113.921327
#   Name: 643, dtype: object),
#  (644,
#   Country                                        Canada
#   Abbreviation                                       CA
#   country_rank                                     14.0
#   Gross tertiary education enrollment (%)          68.9
#   Population                                 36991981.0
#   Unemployment rate                                5.56
#   Urban_population                           30628482.0
#   Latitude                                    56.130366
#   Longitude                                 -106.346771
#   Name: 644, dtype: object),
#  (645,
#   Country                                    United Kingdom
#   Abbreviation                                           GB
#   country_rank                                         34.0
#   Gross tertiary education enrollment (%)              60.0
#   Population                                     66834405.0
#   Unemployment rate                                    3.85
#   Urban_population                               55908316.0
#   Latitude                                        55.378051
#   Longitude                                       -3.435973
#   Name: 645, dtype: object),
#  (646,
#   Country                                    United States
#   Abbreviation                                          US
#   country_rank                                      2774.0
#   Gross tertiary education enrollment (%)             88.2
#   Population                                   328239523.0
#   Unemployment rate                                   14.7
#   Urban_population                             270663028.0
#   Latitude                                        37.09024
#   Longitude                                     -95.712891
#   Name: 646, dtype: object),
#  (647,
#   Country                                         Brazil
#   Abbreviation                                        BR
#   country_rank                                      55.0
#   Gross tertiary education enrollment (%)           51.3
#   Population                                 212559417.0
#   Unemployment rate                                12.08
#   Urban_population                           183241641.0
#   Latitude                                    -14.235004
#   Longitude                                    -51.92528
#   Name: 647, dtype: object),
#  (648,
#   Country                                           India
#   Abbreviation                                         IN
#   country_rank                                      125.0
#   Gross tertiary education enrollment (%)            28.1
#   Population                                 1366417754.0
#   Unemployment rate                                  5.36
#   Urban_population                            471031528.0
#   Latitude                                      20.593684
#   Longitude                                      78.96288
#   Name: 648, dtype: object),
#  (649,
#   Country                                    United Kingdom
#   Abbreviation                                           GB
#   country_rank                                        867.0
#   Gross tertiary education enrollment (%)              60.0
#   Population                                     66834405.0
#   Unemployment rate                                    3.85
#   Urban_population                               55908316.0
#   Latitude                                        55.378051
#   Longitude                                       -3.435973
#   Name: 649, dtype: object),
#  (650,
#   Country                                        Sweden
#   Abbreviation                                       SE
#   country_rank                                      4.0
#   Gross tertiary education enrollment (%)          67.0
#   Population                                 10285453.0
#   Unemployment rate                                6.48
#   Urban_population                            9021165.0
#   Latitude                                    60.128161
#   Longitude                                   18.643501
#   Name: 650, dtype: object)]

# %% [markdown]
# # 전처리

# %% [markdown]
# 오류 데이터, 결측치 보완

# %%
# 채울 수 있는 것들 : 'Youtuber', 'subscribers', 'video views', 'uploads', 'Country',
#                    'created_year', 'created_month', 'created_date'
# 자동으로 채워지는 것들: 'Abbreviation', 'Gross tertiary education enrollment (%)', 'Population',
#                             'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'
corrections = {
    ('Country', 'China', ('Youtuber', 'Title'), ('李子柒 Liziqi', '李子柒 Liziqi')),
    ('rank', 940, ('Youtuber'), ('#Refúgio Mental')),
    ('rank', 101, ('Country'), ('Ireland')),
    ('rank', 816, ('Country'), ('Mexico')),
    ('rank', 973, ('Country'), ('India')),
    ('rank', 926, ('Country'), ('United States')),
    ('rank', 919, ('Country'), ('United States')),
    ('rank', 813, ('Country'), ('United States')),
    ('rank', 104, ('Country'), ('United States')),
    ('category', 'Travel & Events', ('Youtuber', 'Title', 'category'), ('Más SKabeche', 'Más SKabeche', 'Entertainment')),
    ('Youtuber', 'Fede Vigevani', ('Country'), ('Mexico')),
    ('Youtuber', 'Troom Troom PT', ('Country'), ('United States')),
    ('Youtuber', 'YouTube Movies', ('channel_type'), ('Film')),
    ('Youtuber', 'Ishtar Music', ('category'), ('Music')),
    ('Youtuber', 'Ultra Bollywood', ('category', 'channel_type'), ('Film & Animation', 'Film')),
    ('Youtuber', 'YouTube', ('created_year', 'created_month', 'created_date'), (2005, 10, 29)),
    ('Youtuber', '1MILLION Dance Studio', ('uploads', 'Country'), (5900, 'South Korea')),
    ('Youtuber', 'Sandeep Maheshwari', ('uploads', 'Country'), (594, 'India')),
    ('Youtuber', 'TKOR', ('uploads', 'Country'), (1500, 'United States')),
    ('Youtuber', 'MoniLina', ('uploads'), (795)),
    ('Youtuber', 'BRIGHT SIDE', ('uploads', 'created_year', 'created_month', 'created_date'),
     (6400, 2017, 3, 15)),
    ('Youtuber', 'Luisito Comunica', ('uploads', 'created_year', 'created_month', 'created_date'),
     (1200, 2012, 4, 15)),
    ('Youtuber', 'T-Series Apna Punjab', ('uploads', 'created_year', 'created_month', 'created_date'),
     (7700, 2011, 9, 26)),
    ('Youtuber', 'Luis Fonsi', ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (188, 'United States', 2014, 6, 25)),
    ('Youtuber', 'Alfredo Larin', ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1900, 'El Salvador', 2017, 4, 9)),
    ('Youtuber', 'Trap City', ('uploads', 'created_year', 'created_month', 'created_date'),
     (2700, 2012, 10, 13)),
    ('Youtuber', 'Musas', ('uploads', 'created_year', 'created_month', 'created_date', 'Population', 'Latitude','Longitude'),
     (630, 2012, 8, 28, 79535, 42.506389, 1.521389)),
    ('Youtuber', 'Chris Brown', ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (31, 'United States', 2006, 12, 21)),
    ('Youtuber', 'Good Mythical Morning', ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (3300, 'United States', 2008, 9, 17)),
    ('Youtuber', 'The Game Theorists', ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (648, 'United States', 2009, 8, 23)),
    ('Youtuber', 'LEGENDA FUNK', ('uploads', 'created_year', 'created_month', 'created_date'),
     (6100, 2013, 5, 11)),
    ('Youtuber', 'Harry Styles', ('uploads', 'created_year', 'created_month', 'created_date'),
     (17, 2017, 3, 9)),
    ('Youtuber', 'Busy Fun Ltd', ('category', 'uploads', 'Country', 'channel_type', 'created_year', 'created_month', 'created_date'),
     ('Comedy', 210, 'India', 'Comedy', 2019, 4, 6)),
    ('Youtuber', "LooLoo Kids - Nursery Rhymes and Children's Songs", ('Title', 'uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     ("LooLoo Kids - Nursery Rhymes and Children's Songs", 714, 'United States', 2014, 8, 6)),
    ('rank', 976, ('uploads', 'Youtuber', 'created_year', 'created_month', 'created_date'),
     (996, 'Gustavo Paródias', 2014, 4, 4)),
    ('rank', 932, ('subscribers', 'uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (17600000, 394, 'Argentina', 2014, 10, 21)),
    ('rank', 892, ('Youtuber', 'Title', 'uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     ('Knowledge Tv हिन्दी', 'Knowledge Tv हिन्दी', 2900, 'India', 2014, 3, 21)),
    ('rank', 809, ('uploads', 'created_year', 'created_month', 'created_date'),
     (110000, 2017, 12, 11)),
    ('rank', 968, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1900, 'United States', 2019, 8, 27)),
    ('rank', 987, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (2900, 'United States', 2020, 2, 3)),
    ('rank', 15, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (6600, 'India', 2012, 1, 21)),
    ('rank', 52, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (130, 'United States', 2014, 6, 9)),
    ('rank', 49, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (18000, 'Mexico', 2014, 10, 14)),
    ('rank', 63, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (136, 'Chile', 2011, 9, 9)),
    ('rank', 76, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1000, 'United States', 2016, 3, 18)),
    ('rank', 78, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (2300, 'Brazil', 2014, 7, 31)),
    ('rank', 864, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (865, 'South Korea', 2017, 5, 12)),
    ('rank', 936, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (5200, 'India', 2014, 3, 13)),
    ('rank', 831, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1300, 'India', 2015, 5, 11)),
    ('rank', 878, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (6200, 'Brazil', 2013, 11, 30)),
    ('rank', 779, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (8000, 'United States', 2014, 3, 22)),
    ('rank', 778, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (38, 'Germany', 2009, 5, 12)),
    ('rank', 105, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (141, 'United States', 2020, 4, 8)),
    ('rank', 110, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1200, 'India', 2018, 10, 10)),
    ('rank', 114, ('Country', 'created_month'), ('India', 9)),
    ('rank', 115, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (953, 'India', 2017, 8, 14)),
    ('rank', 123, ('Country', 'created_year', 'created_month', 'created_date'),
      ('India',2014, 10, 6)),
    ('rank', 136, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (4700, 'India', 2015, 6, 27)),
    ('rank', 141, ('Country', 'created_date'),
     ("South Korea",19)),
    ('rank', 167, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (2800, 'Indonesia', 2014, 1, 22)),
    ('rank', 170, ('Country'), ('Ireland')),
    ('rank', 179, ('uploads', 'Country', 'created_month', 'created_date'),
     (483, "India", 7, 7)),
    ('rank', 181, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (21000, 'India', 2008, 5, 1)),
    ('rank', 184, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1100, 'Mexico', 2016, 2, 12)),
    ('rank', 189, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (58, 'Canada', 2009, 6, 6)),
    ('rank', 190, ('Country'), ('India')),
    ('rank', 201, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (2400, 'United States',2014, 5, 13)),
    ('rank', 221, ('Youtuber', 'uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     ('Marília Mendonça', 140, 'Brazil', 2013, 5, 13)),
    ('rank', 229, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (316, 'United States', 2013, 8, 7)),
    ('rank', 234, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (225, 'Spain',2015, 10, 18)),
    ('rank', 236, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (180000, 'India',2017, 3, 3)),
    ('rank', 253, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (101, 'India', 2012, 10, 24)),
    ('rank', 265, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (4900, 'India', 2013, 11, 22)),
    ('rank', 270, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1900, 'India', 2010, 3, 16)),
    ('rank', 277, ('Country'),
     ('United States')),
    ('rank', 330, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (8400, 'Saudi Arabia', 2012, 1, 10)),
    ('rank', 331, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (3700, 'India', 2016, 5, 13)),
    ('rank', 339, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (3900,'United States', 2021, 3, 17)),
    ('rank', 349, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (362, 'India', 2019, 4, 25)),
    ('rank', 367, ('uploads', 'Country', 'created_month', 'created_date'),
     (469, 'United States', 10, 15)),
    ('rank', 387, ('Country', 'created_year', 'created_month', 'created_date'),
     ('United States', 2016, 1, 26)),
    ('rank', 395, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (4000, 'Brazil', 2014, 5, 18)),
    ('rank', 441, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1100, 'Brazil', 2016, 2, 16)),
    ('rank', 445, ('category', 'uploads', 'Country', 'channel_type', 'created_year', 'created_month', 'created_date'),
     ('Music', 62, 'United States', 'Music', 2016, 12, 1)),
    ('rank', 451, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (4100, 'United Kingdom', 2006, 9, 14)),
    ('rank', 464, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (950, 'United States', 2018, 5, 10)),
    ('rank', 477, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (962, 'India', 2012, 5, 1)),
    ('rank', 493, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (220, 'Indonesia', 2017, 8, 25)),
    ('rank', 174, ('created_year', 'created_month', 'created_date'),
     (2013, 12, 4)),
    ('rank', 203, ('Country'), ('India')),
    ('rank', 219, ('Country'), ('Sweden')),
    ('rank', 246, ('Country'), ('India')),
    ('rank', 259, ('Country'), ('United States')),
    ('rank', 289, ('Country'), ('India')),
    ('rank', 303, ('Country'), ('India')),
    ('rank', 305, ('Country'), ('Russia')),
    ('rank', 361, ('created_year', 'created_month', 'created_date'),
     (2013, 12, 21)),
    ('rank', 383, ('Youtuber', 'Title', 'Country'),
     ("हिंदी - Genevieve's Playhouse", "हिंदी - Genevieve's Playhouse", 'United States')),
    ('rank', 411, ('Country'), ('United States')),
    ('rank', 426, ('Country'), ('United States')),
    ('rank', 427, ('Country'), ('Canada')),
    ('rank', 432, ('Country'), ('India')),
    ('rank', 433, ('Country'), ('United States')),
    ('rank', 458, ('Country'), ('United States')),
    ('rank', 470, ('Country'), ('India')),
    ('rank', 484, ('Country'), ('South Korea')),
    ('rank', 501, ('Country'), ('United States')),
    ('rank', 524, ('Country'), ('United States')),
    ('rank', 535, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (362, 'United Kingdom', 2012, 10, 7)),
    ('rank', 544, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (552, 'Mexico', 2012, 9, 4)),
    ('rank', 545, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (4700, 'Spain', 2012, 12, 12)),
    ('rank', 546, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (594, 'India', 2021, 5, 26)),
    ('rank', 549, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (781, 'Pakistan', 2013, 10, 30)),
    ('rank', 570, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (74000, 'Indonesia', 2015, 7, 28)),
    ('rank', 591, ('uploads', 'created_year', 'created_month', 'created_date'),
     (506, 2012, 6, 4)),
    ('rank', 596, ('Country'), ('South Korea')),
    ('rank', 17, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (6500, 'United States', 2016, 11, 15)),
    ('rank', 51, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (791, 'Belarus', 2014, 11, 29)),
    ('rank', 62, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (447, 'Norway', 2012, 8, 26)),
    ('rank', 123, ('uploads'), (130)),
    ('rank', 165, ('uploads', 'created_year', 'created_month', 'created_date'),
     (545, 2010, 7, 4)),
    ('rank', 227, ('uploads', 'created_year', 'created_month', 'created_date'),
     (1100, 2009, 6, 17)),
    ('rank', 274, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (2100, 'United States', 2012,7,12)),
    ('rank', 300, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (169, 'United States', 2006,7,25)),
    ('rank', 341, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (273, 'Mexico', 2015,6,29)),
    ('rank', 362, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (55, 'United States', 2005,10,7)),
    ('rank', 378, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (746, 'United States', 2006,11,29)),
    ('rank', 399, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (8600, 'United States', 2005,6,16)),
    ('rank', 412, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (737, 'United States', 2013,9,9)),
    ('rank', 404, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (241, 'Canada', 2011,9,11)),
    ('rank', 555, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (973, 'Mexico', 2007,2,28)),
    ('rank', 601, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (8300, 'Mexico', 2015,7,18)),
    ('rank', 605, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1900, 'Turkey', 2012,11,19)),
    ('rank', 630, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (487,'United States', 2016,7,11)),
    ('rank', 635, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (1300, 'United States', 2017,1,31)),
    ('rank', 669, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (614, 'South Korea', 2018,9,9)),
    ('rank', 681, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (2100, 'United States',2014,1,21)),
    ('rank', 711, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (445, 'United States', 2009,5,1)),
    ('rank', 756, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (613, 'Brazil', 2016,2,24)),
    ('rank', 770, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (952, 'United States', 2011,11,20)),
    ('rank', 801, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (130000, 'India', 2008,3,14)),
    ('rank', 854, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (767, 'India', 2016,11,26)),
    ('rank', 905, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (547,'India', 2020,3,11)),
    ('rank', 662, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (296, 'Mexico', 2016,11,16)),
    ('rank', 688, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (0, 'United States', 2019,8,14)),
    ('rank', 751, ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
     (39,'United States', 2016,2,13)),
#     ('rank', , ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
#      ()),
#     ('rank', , ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
#      ()),
#     ('rank', , ('uploads', 'Country', 'created_year', 'created_month', 'created_date'),
#      ()),
    
    }
for item in corrections:
    youtube.loc[youtube[item[0]]==item[1], item[2]] = item[3]

# 나라와 관련된 정보 null 값 채우기
for _, row in country.iterrows():
    for col in columns[1:]:
        youtube.loc[youtube['Country']==row['Country'], col] = row[col]

# 국가정보 업데이트 (벨라루스, 노르웨이)
columns = ['Abbreviation', 'country_rank', 'Gross tertiary education enrollment (%)',
           'Population', 'Unemployment rate', 'Urban_population',
           'Latitude', 'Longitude']
youtube.loc[youtube['Country']=='Belarus', columns] = [
    'BY', None, None, 9349645, None, None, 53.90, 27.58]
youtube.loc[youtube['Country']=='Norway', columns] = [
    'NO', None, None, 5488984, None, None, 59.92, 10.75]

# category, channel_type 값 변경 및 null 값 채우기
category_dict = {'Movies': 'Film & Animation'}
channel_type_dict = {'Games': 'Gaming',
                'Howto': 'Howto & Style',
                'Tech': 'Science & Technology',
                'Film': 'Film & Animation',
                'People': 'People & Blogs',
                'News': 'News & Politics',
                'Autos': 'Autos & Vehicles',
                'Animals': 'Pets & Animals',
                'Nonprofit': 'Nonprofits & Activism',
               }
for key in category_dict:
    youtube.loc[youtube['category']==key, 'category'] = category_dict[key]
for key in channel_type_dict:
    youtube.loc[youtube['channel_type']==key, 'channel_type'] = channel_type_dict[key]

temp = youtube['category'].isnull()
youtube.loc[temp, 'category'] = youtube.loc[temp, 'channel_type']
temp = youtube['channel_type'].isnull()
youtube.loc[temp, 'channel_type'] = youtube.loc[temp, 'category']

# %%
# 수정이 잘 되었는지 row별로 확인
youtube[youtube['rank'] == 784].T
# Out:
#                                                      783
# rank                                                 784
# Youtuber                                 #Refugio Mental
# subscribers                                     14100000
# video views                                 3594936775.0
# category                                   Entertainment
# Title                                    #Refugio Mental
# uploads                                              846
# Country                                              NaN
# Abbreviation                                         NaN
# channel_type                               Entertainment
# video_views_rank                                  2218.0
# country_rank                                         NaN
# channel_type_rank                                  155.0
# video_views_for_the_last_30_days               6942000.0
# lowest_monthly_earnings                           1700.0
# highest_monthly_earnings                         27800.0
# lowest_yearly_earnings                           20800.0
# highest_yearly_earnings                         333200.0
# subscribers_for_last_30_days                         NaN
# created_year                                      2013.0
# created_month                                        8.0
# created_date                                        10.0
# Gross tertiary education enrollment (%)              NaN
# Population                                           NaN
# Unemployment rate                                    NaN
# Urban_population                                     NaN
# Latitude                                             NaN
# Longitude                                            NaN

# %%
youtube[youtube['uploads'] < 10].drop(index=[1, 5, 12, 18, 102, 173, 286, 360, 386, 592, 606, 687, 700, 951, ])
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, Title, uploads, Country, Abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, Gross tertiary education enrollment (%), Population, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 28 columns]

# %%
youtube[youtube['Country'].isnull()].drop(index=[
    5, 12, 57, 74, 102, 173, 331, 360, 518, 590, 592, 601, 624, 699, 765, 783, 784, 805, 889, 939, 951])
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, Title, uploads, Country, Abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, Gross tertiary education enrollment (%), Population, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# 날짜

# %%
from datetime import date
def to_date(x):
    return np.nan if x.isnull().sum() else date(int(x[0]), int(x[1]), int(x[2]))
youtube['created'] = youtube[['created_year', 'created_month', 'created_date']].apply(to_date, axis=1)

# %%
# 트렌드 주제: 특정 카테고리가 시간이 지남에 따라 인기를 얻는가.

# %%
# rank : 순위 : 구독자 수 기준 유튜브 채널 위치
# Youtuber : 유튜버 : 유튜브 채널명
# subscribers : 구독자: 채널에 대한 구독자 수
# video views : 비디오 조회수: 채널의 모든 비디오에 대한 총 조회수
# category : 카테고리: 채널의 카테고리 또는 틈새
# Title : 제목 : 유튜브 채널의 제목
# uploads : 업로드: 채널에 업로드된 총 동영상 수
# Country : 국가: 유튜브 채널이 개설된 국가
# Abbreviation : 약칭: 국가의 약칭
# channel_type : 유튜브 채널의 유형(예: 개인, 브랜드)
# video_views_rank : 총 동영상 조회수 기준 채널 순위
# country_rank : 자국 내 가입자 수 기준 채널 순위
# channel_type_rank : 채널의 종류(개별 또는 브랜드)에 따른 순위
# video_views_for_last_30_days: 최근 30일 동안의 총 비디오 조회수
# lowest_monthly_earnings : 가장 낮은_월간 수익: 채널의 가장 낮은 월 예상 수익
# highest_monthly_earnings : 가장 높은_월간 수익: 채널의 가장 높은 월 예상 수익
# lowest_yearly_earnings : 가장 낮은_연b간 수익: 채널의 가장 낮은 추정 연간 수익
# highest_yearly_earnings : 최고 _연간 _ 수익 : 채널의 최고 예상 연간 수익
# subscribers_for_last_30_days: 최근 30일 동안 얻은 새 가입자 수
# created_year: 유튜브 채널이 생성된 연도
# created_Month : 유튜브 채널이 생성된 달
# created_date : 유튜브 채널 생성 정확한 날짜
# Gross tertiary education enrollment (%) : 고등 교육 총 등록자(%): 국가에서 고등 교육에 등록한 인구의 비율
# Population : 인구: 해당 국가의 총 인구
# Unemployment rate : 실업률: 해당 국가의 실업률
# Urban_population : 도시_인구: 도시지역에 거주하는 인구의 비율
# Latitude : 위도: 국가 위치의 위도 좌표
# Longtitude : 경도: 국가 위치의 경도 좌표

# %% [markdown]
# ## 트렌드 주제: 특정 카테고리가 시간이 지남에 따라 인기를 얻는가.

# %% [markdown]
# - 각 카테고리 마다 생성된 채널의 년도를 기반으로 카테고리의 인기를 분석한다.

# %% [markdown]
# - 결측치 제거

# %%
youtube_dropna = youtube.dropna(subset=['category'])

# %%
youtube_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 993 entries, 0 to 994
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     993 non-null    int64
#  1   Youtuber                                 993 non-null    object
#  2   subscribers                              993 non-null    int64
#  3   video views                              993 non-null    float64
#  4   category                                 993 non-null    object
#  5   Title                                    993 non-null    object
#  6   uploads                                  993 non-null    int64
#  7   Country                                  974 non-null    object
#  8   Abbreviation                             972 non-null    object
#  9   channel_type                             993 non-null    object
#  10  video_views_rank                         992 non-null    float64
#  11  country_rank                             972 non-null    float64
#  12  channel_type_rank                        962 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  993 non-null    float64
#  15  highest_monthly_earnings                 993 non-null    float64
#  16  lowest_yearly_earnings                   993 non-null    float64
#  17  highest_yearly_earnings                  993 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             993 non-null    float64
#  20  created_month                            993 non-null    float64
#  21  created_date                             993 non-null    float64
#  22  Gross tertiary education enrollment (%)  969 non-null    float64
#  23  Population                               972 non-null    float64
#  24  Unemployment rate                        969 non-null    float64
#  25  Urban_population                         969 non-null    float64
#  26  Latitude                                 972 non-null    float64
#  27  Longitude                                972 non-null    float64
#  28  created                                  993 non-null    object
# dtypes: float64(19), int64(3), object(7)
# memory usage: 232.7+ KB

# %% [markdown]
# - 생성년도와 구독자의 평균을 카테고리별로 그룹화한다.

# %%
youtube_category_group = youtube_dropna.groupby('category').agg({'created_year' : 'mean',
                                       'subscribers': 'mean'}).sort_values('created_year')

# %%
youtube_category_group['category'] = youtube_category_group.index

# %%
plt.figure(figsize=(16, 8))
plt.xlim(2000,2017)

sns.set(font_scale=1.2)
sns.barplot(x = youtube_category_group['created_year'], y = youtube_category_group['category'], orient='h', palette='winter')
plt.savefig('category_years1.png')

# %%
youtube_sorted = youtube_dropna.groupby('created_year')['category'].value_counts().reset_index().sort_values(by=['created_year', 'count'], ascending=False)
youtube_sorted[youtube_sorted.created_year == 2005]
# Out:
#    created_year              category  count
# 0        2005.0                 Music      8
# 1        2005.0         Entertainment      6
# 2        2005.0        People & Blogs      2
# 3        2005.0       News & Politics      2
# 4        2005.0                Comedy      1
# 5        2005.0                Gaming      1
# 6        2005.0        Pets & Animals      1
# 7        2005.0  Science & Technology      1
# 8        2005.0                Sports      1

# %% [markdown]
# - 각 년도 별로 가장 인기있었던 카테고리

# %%
df = pd.DataFrame(columns=['created_year','category','count'])
index = 0

for year in youtube_sorted.created_year.unique():
    df.loc[index] = youtube_sorted[youtube_sorted.created_year == year].iloc[0,:]
    index += 1
df
# Out:
#    created_year        category count
# 0        2022.0   Entertainment     2
# 1        2021.0  People & Blogs     8
# 2        2020.0   Entertainment     8
# 3        2019.0   Entertainment    14
# 4        2018.0   Entertainment    15
# 5        2017.0  People & Blogs    24
# 6        2016.0  People & Blogs    18
# 7        2015.0   Entertainment    27
# 8        2014.0   Entertainment    25
# 9        2013.0   Entertainment    20
# 10       2012.0           Music    20
# 11       2011.0           Music    24
# 12       2010.0           Music    17
# 13       2009.0           Music    27
# 14       2008.0           Music    15
# 15       2007.0           Music    17
# 16       2006.0   Entertainment    22
# 17       2005.0           Music     8

# %% [markdown]
# ## 결론
# - 2000년대 후반 -> Sports, Autos & Vehicles 가 인기 있었다.
# - 2010년대 초반 -> News & Politics, Music, Shows, Science & Technology, Nonprofits &  Activism, Gaming, Film & Animation, Entertainment, Pets & Animals, Comedy, Howto & Style 가 인기 있었다.
# - 2010년대 중반 -> Education, People & Blogs 가 인기 있었다.
# - Entertainment, Music, People & Blogs 순으로 각 년도마다 많은 인기를 가짐
